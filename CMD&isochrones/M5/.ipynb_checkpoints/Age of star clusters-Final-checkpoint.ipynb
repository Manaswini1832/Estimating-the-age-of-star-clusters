# %%
import numpy as np
import matplotlib.pyplot as plt
T= np.loadtxt('Isochrone_data.txt',usecols=(2), unpack =True )
L= np.loadtxt('Isochrone_data.txt',usecols=(4), unpack =True )
plt.plot(T, L, label='10.62Gyr')
plt.xlabel('Log(Teff)')
plt.ylabel('Log L/Lo')
# plt.axis([5.0, 3.5, 0, 6])
plt.legend(loc='lower left')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
u= np.loadtxt('Isochrone_data2.txt',usecols=(5), unpack =True )
g= np.loadtxt('Isochrone_data2.txt',usecols=(6), unpack =True )
diff = u-g
plt.plot(diff, u, 'k')
plt.xlabel('u-g')
plt.ylabel('u')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("Data_5.csv",encoding="utf-8").fillna(0)
x = data['u-g'].iloc[0:].values
y = data['u'].iloc[0:].values
plt.xlabel("u-g")
plt.ylabel("u")
plt.title("H-R diagram")
plt.scatter(x,y,color='r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("Data_5.csv",encoding="utf-8").fillna(0)
x = data['u-g'].iloc[0:].values
y = data['u'].iloc[0:].values
plt.xlabel("u-g")
plt.ylabel("u")
plt.title("H-R diagram")
plt.scatter(x,y-14,marker='+',zorder=2)

u= np.loadtxt('Isochrone_data2.txt',usecols=(5), unpack =True )
g= np.loadtxt('Isochrone_data2.txt',usecols=(6), unpack =True )
diff = u-g
plt.plot(diff, u, 'k',zorder=1)
plt.xlabel('u-g')
plt.ylabel('u')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("Data_3.csv",encoding="utf-8").fillna(0)
x = data['u-g'].iloc[0:].values
y = data['u'].iloc[0:].values
plt.xlabel("u-g")
plt.ylabel("u")
plt.title("H-R diagram")
plt.scatter(x,y,marker='+',zorder=2)



u= np.loadtxt('Isochrone_data2.txt',usecols=(5), unpack =True )
g= np.loadtxt('Isochrone_data2.txt',usecols=(6), unpack =True )
diff = u-g
plt.plot(diff, u+10, 'k',zorder=1)
plt.xlabel('u-g')
plt.ylabel('u')



plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("AD9.csv",encoding="utf-8").fillna(0)
x = data['u-g'].iloc[0:].values
y = data['u'].iloc[0:].values
plt.xlabel("u-g")
plt.ylabel("u")
plt.title("H-R diagram")
plt.scatter(x,y,marker='+',zorder=2)


u= np.loadtxt('Isochrone_data2.txt',usecols=(5), unpack =True )
g= np.loadtxt('Isochrone_data2.txt',usecols=(6), unpack =True )
diff = u-g
plt.plot(diff, u+14, 'k',zorder=1)
plt.xlabel('u-g')
plt.ylabel('u')

plt.show()
plt.savefig('Isochrone-fitting.png')

# %% [markdown]
# FOLLOWING ARE THE FINAL PLOTS

# %% [markdown]
# 1) PLOT OF THE .CSV FILE FOR THE M5 CLUSTER

# %%
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("SDSS data.csv",encoding="utf-8").fillna(0)
x = data['u-g'].iloc[0:].values
y = data['u'].iloc[0:].values
plt.xlabel("u-g")
plt.ylabel("u")
plt.title("CMD")
plt.ylim(32, 15)
plt.xlim(-4, 5)
plt.scatter(x,y,marker='+',zorder=2)
plt.savefig('CMD.png')
plt.show()

# %% [markdown]
# 2) ISOCHRONE PLOT

# %%
import numpy as np
import matplotlib.pyplot as plt

u= np.loadtxt('Isochrone data.txt',usecols=(5), unpack =True )
g= np.loadtxt('Isochrone data.txt',usecols=(6), unpack =True )
diff = u-g
plt.plot(diff, u+14, 'k',zorder=1)
plt.xlabel('u-g')
plt.ylabel('u')
plt.savefig('Isochrone.png')
plt.show()

# %% [markdown]
# 3) ISOCHRONE FITTING

# %%
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("SDSS data.csv",encoding="utf-8").fillna(0)
x = data['u-g'].iloc[0:].values
y = data['u'].iloc[0:].values
plt.xlabel("u-g")
plt.ylabel("u")
plt.title("Isochrone fitting")
plt.ylim(32, 15)
plt.xlim(-4, 5)
plt.scatter(x,y,marker='+',zorder=2)


u= np.loadtxt('Isochrone data.txt',usecols=(5), unpack =True )
g= np.loadtxt('Isochrone data.txt',usecols=(6), unpack =True )
diff = u-g
plt.plot(diff, u+15, 'k',zorder=1)
plt.xlabel('u-g')
plt.ylabel('u')
plt.savefig('Isochrone-fitted.png')
plt.show()

# %% [markdown]
# Here are the CMD, Isochrone and Isochrone-fitting plots for ugriz r and r-i

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("SDSS data.csv",encoding="utf-8").fillna(0)
x = data['r-i'].iloc[0:].values
y = data['r'].iloc[0:].values
plt.xlabel("r-i")
plt.ylabel("r")
plt.title("CMD")
plt.ylim(26, 14)
plt.scatter(x,y,marker='+',zorder=2)
plt.savefig('CMD2.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

r= np.loadtxt('Isochrone data.txt',usecols=(7), unpack =True )
i= np.loadtxt('Isochrone data.txt',usecols=(8), unpack =True )
diff = r-i
plt.plot(diff, u+14, 'k',zorder=1)
plt.xlabel('r-i')
plt.ylabel('r')
plt.savefig('Isochrone2.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("SDSS data.csv",encoding="utf-8").fillna(0)
x = data['r-i'].iloc[0:].values
y = data['r'].iloc[0:].values
plt.xlabel("r-i")
plt.ylabel("r")
plt.ylim(26, 14)
plt.title("Isochrone fitting")
plt.scatter(x,y,marker='+',zorder=2)


import numpy as np
import matplotlib.pyplot as plt

r= np.loadtxt('Isochrone data.txt',usecols=(7), unpack =True )
i= np.loadtxt('Isochrone data.txt',usecols=(8), unpack =True )
diff = r-i
plt.plot(diff, u+15, 'k',zorder=1)
plt.xlabel('r-i')
plt.ylabel('r')
plt.savefig('Isochrone2.png')
plt.show()

# %% [markdown]
# Here are the CMD, Isochrone and Isochrone fitting plots for i and i-z

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("SDSS data.csv",encoding="utf-8").fillna(0)
x = data['i-z'].iloc[0:].values
y = data['i'].iloc[0:].values
plt.xlabel("i-z")
plt.ylabel("i")
plt.title("CMD")
plt.ylim(24, 12)
plt.scatter(x,y,marker='+',zorder=2)
plt.savefig('CMD3.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

i= np.loadtxt('Isochrone data.txt',usecols=(8), unpack =True )
z= np.loadtxt('Isochrone data.txt',usecols=(9), unpack =True )
diff = i-z
plt.plot(diff, u+14, 'k',zorder=1)
plt.xlabel('i-z')
plt.ylabel('i')
plt.savefig('Isochrone3.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("SDSS data.csv",encoding="utf-8").fillna(0)
x = data['i-z'].iloc[0:].values
y = data['i'].iloc[0:].values
plt.xlabel("i-z")
plt.ylabel("i")
plt.title("Isochrone fitting")
plt.ylim(24, 12)
plt.scatter(x,y,marker='+',zorder=2)

import numpy as np
import matplotlib.pyplot as plt
i= np.loadtxt('Isochrone data.txt',usecols=(8), unpack =True )
z= np.loadtxt('Isochrone data.txt',usecols=(9), unpack =True )
diff = i-z
plt.plot(diff, u+7, 'k',zorder=1)
plt.xlabel('i-z')
plt.ylabel('i')
plt.savefig('Isochronefitted3.png')
plt.show()
